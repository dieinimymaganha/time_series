# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Carregando a base de co2

# %%
co2 = pd.read_csv('sample_data/co2.csv', delimiter='\t')
co2.head()
# Out:
#        data   media
# 0  1980.042  338.45
# 1  1980.125  339.15
# 2  1980.208  339.48
# 3  1980.292  339.87
# 4  1980.375  340.30

# %% [markdown]
# Carregando a base de Nascimento

# %%
plt.plot(co2.data, co2.media)
plt.ylabel('Média')
plt.xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
nasc = pd.read_csv('sample_data/nascimentos.csv')
nasc.head()
# Out:
#          data  n_nasc
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
plt.plot(nasc.data, nasc.n_nasc)
plt.ylabel('Nascimento')
plt.xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# Convertendo coluna data para tipo datetime

# %%
nasc.data = pd.to_datetime(nasc.data)

# %%
plt.plot(nasc.data, nasc.n_nasc)
plt.ylabel('Nascimento')
plt.xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')
